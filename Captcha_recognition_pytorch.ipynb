# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !unzip '/gdrive/My Drive/captcha-recognition-pytorch/captcha-recognition-pytorch-master.zip'
# Out:
# Archive:  /gdrive/My Drive/captcha-recognition-pytorch/captcha-recognition-pytorch-master.zip
#    creating: captcha-recognition-pytorch-master/
#   inflating: captcha-recognition-pytorch-master/.gitignore
#   inflating: captcha-recognition-pytorch-master/config.py
#   inflating: captcha-recognition-pytorch-master/dataset.py
#   inflating: captcha-recognition-pytorch-master/engine.py
#    creating: captcha-recognition-pytorch-master/input/
#    creating: captcha-recognition-pytorch-master/input/captcha_images_v2/
#   inflating: captcha-recognition-pytorch-master/input/captcha_images_v2/226md.png
#   inflating: captcha-recognition-pytorch-master/input/captcha_images_v2/22d5n.png
#   inflating: captcha-recognition-pytorch-master/input/captcha_images_v2/2356g.png
#   inflating: captcha-recognition-pytorch-master/input/captcha_images_v2/23mdg.png
#   inflating: captcha-recognition-pytorch-master/input/captcha_images_v2/23n88.png
# ...

# %%
cd /content/captcha-recognition-pytorch-master
# Out:
# /content/captcha-recognition-pytorch-master

# %%
# !python train.py
# Out:
# 100% 117/117 [00:08<00:00, 13.15it/s]
# 100% 13/13 [00:00<00:00, 14.49it/s]
# [('7gce6', ''), ('d7nn3', ''), ('n6nn2', ''), ('my84e', ''), ('w75w8', ''), ('fp3wy', ''), ('fp382', ''), ('7p852', ''), ('8ne4g', ''), ('53wp3', '')]
# Epoch=0, Train Loss=9.399034679445446, Test Loss=3.3899987110724816 Accuracy=0.0
# 100% 117/117 [00:08<00:00, 13.79it/s]
# 100% 13/13 [00:00<00:00, 15.23it/s]
# [('7gce6', ''), ('d7nn3', ''), ('n6nn2', ''), ('my84e', ''), ('w75w8', ''), ('fp3wy', ''), ('fp382', ''), ('7p852', ''), ('8ne4g', ''), ('53wp3', '')]
# Epoch=1, Train Loss=3.3748327992920184, Test Loss=3.3435511589050293 Accuracy=0.0
# 100% 117/117 [00:08<00:00, 13.69it/s]
# 100% 13/13 [00:00<00:00, 14.97it/s]
# [('7gce6', ''), ('d7nn3', ''), ('n6nn2', ''), ('my84e', ''), ('w75w8', ''), ('fp3wy', ''), ('fp382', ''), ('7p852', ''), ('8ne4g', ''), ('53wp3', '')]
# Epoch=2, Train Loss=3.3344308983566413, Test Loss=3.313426036101121 Accuracy=0.0
# 100% 117/117 [00:08<00:00, 13.72it/s]
# ...
